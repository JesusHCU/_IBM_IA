# %%
import pandas as pd
import os 
os.getcwd()
# Out:
# 'C:\\Users\\roman\\Programa IA IBM\\Curso\\Sesiónes\\Python Data Science'

# %%
peliculas = pd.read_csv("C:\\Users\\roman\\Programa IA IBM\\Curso\\Sesiónes\\Python Data Science\\Datos Ejer python\\Seccion 6\\RatingsPeliculas.csv")

# %%
peliculas.head()
# Out:
#                 Pelicula    Genero  Ratings de Rotten Tomatoes %  \
# 0  (500) Days of Summer    Comedia                            87
# 1            10,000 B.C.  Aventura                             9
# 2             12 Rounds     Accion                            30
# 3              127 Hours  Aventura                            93
# 4              17 Again    Comedia                            55
#
#    Ratings de la Audience %  Presupuesto (millones USD)  Lanzamiento
# 0                        81                           8         2009
# 1                        44                         105         2008
# 2                        52                          20         2009
# 3                        84                          18         2010
# 4                        70                          20         2009

# %%
len(peliculas)
# Out:
# 559

# %%
peliculas.columns
# Out:
# Index(['Pelicula', 'Genero', 'Ratings de Rotten Tomatoes %',
#        'Ratings de la Audience %', 'Presupuesto (millones USD)',
#        'Lanzamiento'],
#       dtype='object')

# %%
peliculas.columns = ["Pelicula", "Genero", "RatingsCriticos", "RatingsAudiencia", "PresupuestoMillones", "Año"]

# %%
peliculas.head()
# Out:
#                 Pelicula    Genero  RatingsCriticos  RatingsAudiencia  \
# 0  (500) Days of Summer    Comedia               87                81
# 1            10,000 B.C.  Aventura                9                44
# 2             12 Rounds     Accion               30                52
# 3              127 Hours  Aventura               93                84
# 4              17 Again    Comedia               55                70
#
#    PresupuestoMillones   Año
# 0                    8  2009
# 1                  105  2008
# 2                   20  2009
# 3                   18  2010
# 4                   20  2009

# %%
peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Pelicula             559 non-null    object
#  1   Genero               559 non-null    object
#  2   RatingsCriticos      559 non-null    int64
#  3   RatingsAudiencia     559 non-null    int64
#  4   PresupuestoMillones  559 non-null    int64
#  5   Año                  559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
peliculas.describe()
# Out:
#        RatingsCriticos  RatingsAudiencia  PresupuestoMillones          Año
# count       559.000000        559.000000           559.000000   559.000000
# mean         47.309481         58.744186            50.236136  2009.152057
# std          26.413091         16.826887            48.731817     1.362632
# min           0.000000          0.000000             0.000000  2007.000000
# 25%          25.000000         47.000000            20.000000  2008.000000
# 50%          46.000000         58.000000            35.000000  2009.000000
# 75%          70.000000         72.000000            65.000000  2010.000000
# max          97.000000         96.000000           300.000000  2011.000000

# %%
peliculas.Pelicula
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Pelicula, Length: 559, dtype: object

# %%
peliculas.Pelicula.astype("category")
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Pelicula, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
peliculas.Pelicula
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Pelicula, Length: 559, dtype: object

# %%
peliculas.Pelicula = peliculas.Pelicula.astype("category")

# %%
peliculas.Pelicula
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Pelicula, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
peliculas.head()
# Out:
#                 Pelicula    Genero  RatingsCriticos  RatingsAudiencia  \
# 0  (500) Days of Summer    Comedia               87                81
# 1            10,000 B.C.  Aventura                9                44
# 2             12 Rounds     Accion               30                52
# 3              127 Hours  Aventura               93                84
# 4              17 Again    Comedia               55                70
#
#    PresupuestoMillones   Año
# 0                    8  2009
# 1                  105  2008
# 2                   20  2009
# 3                   18  2010
# 4                   20  2009

# %%
peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Pelicula             559 non-null    category
#  1   Genero               559 non-null    object
#  2   RatingsCriticos      559 non-null    int64
#  3   RatingsAudiencia     559 non-null    int64
#  4   PresupuestoMillones  559 non-null    int64
#  5   Año                  559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
peliculas.Genero = peliculas.Genero.astype("category")
peliculas.Año = peliculas.Año.astype("category")

# %%
peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Pelicula             559 non-null    category
#  1   Genero               559 non-null    category
#  2   RatingsCriticos      559 non-null    int64
#  3   RatingsAudiencia     559 non-null    int64
#  4   PresupuestoMillones  559 non-null    int64
#  5   Año                  559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
peliculas.Genero.cat.categories
# Out:
# Index(['Accion', 'Aventura', 'Comedia', 'Drama', 'Romance', 'Suspenso',
#        'Terror'],
#       dtype='object')

# %%
peliculas.Pelicula.cat.categories
# Out:
# Index(['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours',
#        '17 Again ', '2012', '27 Dresses', '30 Days of Night',
#        '30 Minutes or Less', '50/50',
#        ...
#        'Yes Man', 'Yogi Bear', 'You Again', 'You Don't Mess with the Zohan',
#        'You Will Meet a Tall Dark Stranger', 'Your Highness',
#        'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper'],
#       dtype='object', length=559)

# %%
peliculas.Año.cat.categories
# Out:
# Index([2007, 2008, 2009, 2010, 2011], dtype='int64')

# %%
peliculas.describe()
# Out:
#        RatingsCriticos  RatingsAudiencia  PresupuestoMillones
# count       559.000000        559.000000           559.000000
# mean         47.309481         58.744186            50.236136
# std          26.413091         16.826887            48.731817
# min           0.000000          0.000000             0.000000
# 25%          25.000000         47.000000            20.000000
# 50%          46.000000         58.000000            35.000000
# 75%          70.000000         72.000000            65.000000
# max          97.000000         96.000000           300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns 
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
#Joimtplots

# %%
j = sns.jointplot(data=peliculas, x = "RatingsCriticos", y= "RatingsAudiencia")

# %%
#grafico 1
h = sns.jointplot(data=peliculas, x = "RatingsCriticos", y= "RatingsAudiencia", kind = "hex")

# %%
#Histograma

# %%
#El metodo ya conocido
m1= sns.distplot(peliculas.RatingsAudiencia, bins=15)

# %%
m2= sns.distplot(peliculas.RatingsCriticos, bins=15)

# %%
#Diagramas

# %%
n1=plt.hist(peliculas.RatingsAudiencia, bins=15)

# %%
n2=plt.hist(peliculas.RatingsCriticos, bins=15)

# %%
#histograma Apilados

# %%
peliculas.Genero=="Drama"
#plt.hist(peliculas.PresupuestoMillones)
#plt.show()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 554    False
# 555    False
# 556    False
# 557    False
# 558    False
# Name: Genero, Length: 559, dtype: bool

# %%
peliculas[peliculas.Genero=="Drama"]
# Out:
#                 Pelicula Genero  RatingsCriticos  RatingsAudiencia  \
# 10            88 Minutes  Drama                5                51
# 11    A Dangerous Method  Drama               79                89
# 13        A Serious Man   Drama               89                64
# 18          Albert Nobbs  Drama               53                43
# 23       All Good Things  Drama               33                64
# ..                   ...    ...              ...               ...
# 529            War Horse  Drama               77                73
# 532  Water For Elephants  Drama               60                72
# 534     We Own the Night  Drama               55                63
# 541             Whip It   Drama               84                73
# 545        Winter's Bone  Drama               94                73
#
#      PresupuestoMillones   Año
# 10                    30  2007
# 11                    20  2011
# 13                     7  2009
# 18                     8  2011
# ...

# %%
peliculas[peliculas.Genero=="Drama"].PresupuestoMillones
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: PresupuestoMillones, Length: 101, dtype: int64

# %%
plt.hist(peliculas[peliculas.Genero=="Accion"].PresupuestoMillones, bins=15)
plt.hist(peliculas[peliculas.Genero=="Drama"].PresupuestoMillones, bins=15)
plt.hist(peliculas[peliculas.Genero=="Suspenso"].PresupuestoMillones, bins=15)
plt.show()

# %%
[peliculas[peliculas.Genero=="Accion"].PresupuestoMillones, peliculas[peliculas.Genero=="Drama"].PresupuestoMillones]
# Out:
# [2       20
#  5      200
#  15      35
#  29      20
#  30      20
#        ...
#  531    130
#  542     35
#  546    150
#  547    160
#  557     24
#  Name: PresupuestoMillones, Length: 154, dtype: int64,
#  10     30
#  11     20
#  13      7
#  18      8
#  23     20
#         ..
#  529    66
#  532    38
#  534    21
#  541    15
#  545     2
#  Name: PresupuestoMillones, Length: 101, dtype: int64]

# %%
plt.hist([peliculas[peliculas.Genero=="Accion"].PresupuestoMillones, peliculas[peliculas.Genero=="Drama"].PresupuestoMillones], bins=15, stacked=True)
plt.show()

# %%
for gen in peliculas.Genero.cat.categories:
    print(gen)
# Out:
# Accion
# Aventura
# Comedia
# Drama
# Romance
# Suspenso
# Terror

# %%
lista1 =list()
mis_etiquetas = list()
for gen in peliculas.Genero.cat.categories:
    lista1.append(peliculas[peliculas.Genero==gen].PresupuestoMillones)
    mis_etiquetas.append(gen)
h = plt.hist(lista1, bins=30, stacked=True, rwidth= 0.8, label=mis_etiquetas)
plt.legend()
plt.show()

# %%
#Grafico de KDE

# %%
vis1 = sns.lmplot(data=peliculas, x="RatingsCriticos", y="RatingsAudiencia", fit_reg=False, hue="Genero", height=6, aspect=1)

# %%
k1=sns.kdeplot([peliculas.RatingsCriticos, peliculas.RatingsAudiencia])

# %%
 k1 = sns.kdeplot(x = peliculas.RatingsCriticos, y = peliculas.RatingsAudiencia)

# %%
sns.set_style("darkgrid")
k2 = sns.kdeplot(x = peliculas.RatingsCriticos, y = peliculas.RatingsAudiencia, shade=True, shade_lowest=False)

# %%
 k3 = sns.kdeplot(x = peliculas.RatingsCriticos, y = peliculas.RatingsAudiencia, shade=True, shade_lowest=False, cmap="Reds")

# %%
sns.set_style("darkgrid")
k1 = sns.kdeplot(x = peliculas.RatingsCriticos, y = peliculas.RatingsAudiencia, shade=True, shade_lowest=False, cmap="Reds")
k2 = sns.kdeplot(x = peliculas.RatingsCriticos, y = peliculas.RatingsAudiencia, cmap="Reds")

# %%
#Trabajando con Subplots()

# %%
from matplotlib import pyplot as plt
import seaborn as sns 
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
sns.set_style("dark")
k1 = sns.kdeplot(x = peliculas.PresupuestoMillones, y = peliculas.RatingsAudiencia)

# %%
k1 = sns.kdeplot(x = peliculas.PresupuestoMillones, y = peliculas.RatingsCriticos)

# %%
f, ax = plt.subplots(1,2, figsize=(12,6))

# %%
f, axes = plt.subplots(1,2, figsize=(12,6))
k1 = sns.kdeplot(x = peliculas.PresupuestoMillones, y = peliculas.RatingsAudiencia)
k2 = sns.kdeplot(x = peliculas.PresupuestoMillones, y = peliculas.RatingsCriticos)

# %%
f, ax = plt.subplots(1,2, figsize=(12,6))
k1 = sns.kdeplot(x = peliculas.PresupuestoMillones, y = peliculas.RatingsAudiencia, ax=ax[0])
k2 = sns.kdeplot(x = peliculas.PresupuestoMillones, y = peliculas.RatingsCriticos, ax=ax[1])

# %%
f, ax = plt.subplots(1,2, figsize=(12,6), sharex=True, sharey=True)
k1 = sns.kdeplot(x = peliculas.PresupuestoMillones, y = peliculas.RatingsAudiencia, ax=ax[0])
k2 = sns.kdeplot(x = peliculas.PresupuestoMillones, y = peliculas.RatingsCriticos, ax=ax[1])
k1.set(xlim=(-60,250))
k2.set(xlim=(-60,250))
# Out:
# [(-60.0, 250.0)]

# %%
f, ax = plt.subplots(2,2, figsize=(12,6), sharex=True, sharey=True)
k1 = sns.kdeplot(x = peliculas.PresupuestoMillones, y = peliculas.RatingsAudiencia, ax=ax[0,0])
k2 = sns.kdeplot(x = peliculas.PresupuestoMillones, y = peliculas.RatingsCriticos, ax=ax[1,0])
k1.set(xlim=(-60,250))
k2.set(xlim=(-60,250))
# Out:
# [(-60.0, 250.0)]

# %%
#Driagramas de Violin

# %%
z = sns.boxplot(data= peliculas, x="Genero", y="RatingsCriticos", hue="Genero")

# %%
z = sns.violinplot(data= peliculas, x="Genero", y="RatingsCriticos", hue="Genero")

# %%
w=sns.boxplot(data=peliculas[peliculas.Genero=="Drama"], x="Año", y="RatingsCriticos", hue="Año", legend=None)

# %%
z=sns.violinplot(data=peliculas[peliculas.Genero=="Drama"], x="Año", y="RatingsCriticos", hue="Año", legend=None)

# %%
#Creando un FacetGrid

# %%
g= sns.FacetGrid(peliculas, row="Genero", col="Año", hue="Genero")

# %%
#g=g.map()
#plt.scatter(peliculas.RatingsCriticos, peliculas.RatingsAudiencia)
g= sns.FacetGrid(peliculas, row="Genero", col="Año", hue="Genero")
g=g.map(plt.scatter, "RatingsCriticos", "RatingsAudiencia")

# %%
#Se puede rellenar con cualquier tipo de grafico. Ejemplo:Histograma
g= sns.FacetGrid(peliculas, row="Genero", col="Año", hue="Genero")
g= g.map(plt.hist, "PresupuestoMillones")

# %%
#Regreso a los diagramas de dispersion
#g= sns.FacetGrid(peliculas, row="Genero", col="Año", hue="Genero")
#g=g.map(plt.scatter, "RatingsCriticos", "RatingsAudiencia", **kws)
kws=dict(s=50, linewidth=0.5, edgecolor="black")
kws
# Out:
# {'s': 50, 'linewidth': 0.5, 'edgecolor': 'black'}

# %%
g= sns.FacetGrid(peliculas, row="Genero", col="Año", hue="Genero")
g=g.map(plt.scatter, "RatingsCriticos", "RatingsAudiencia", **kws)

# %%
#Controlando ejes y Agregar Diagonales

# %%
#Driagrama 5
g= sns.FacetGrid(peliculas, row="Genero", col="Año", hue="Genero")
kws=dict(s=50, linewidth=0.5, edgecolor="black")
g=g.map(plt.scatter, "RatingsCriticos", "RatingsAudiencia", **kws)
g.set(xlim=(0,100), ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100),(0,100), c="gray", ls="--")
g.add_legend()

# %%
#Contruyendo Dashboards

# %%
#Import
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
sns.set_style("darkgrid")
f, ax = plt.subplots(2,2, figsize=(15,15), sharey=True)
k1 = sns.kdeplot(x=peliculas.PresupuestoMillones, y=peliculas.RatingsAudiencia, ax=ax[0,0])
k2 = sns.kdeplot(x=peliculas.PresupuestoMillones, y=peliculas.RatingsCriticos, ax=ax[0,1])
k1.set(xlim=(-40,250))
k2.set(xlim=(-40,220))
w=sns.boxplot(data=peliculas[peliculas.Genero=="Drama"], x="Año", y="RatingsCriticos", hue="Año", ax=ax[1,0])
z = sns.violinplot(data= peliculas, x="Genero", y="RatingsCriticos", hue="Genero", ax=ax[1,1])

# %%
sns.set_style("darkgrid")
f, ax = plt.subplots(2,2, figsize=(15,15), sharey=True)
k1 = sns.kdeplot(x=peliculas.PresupuestoMillones, y=peliculas.RatingsAudiencia, ax=ax[0,0])
k2 = sns.kdeplot(x=peliculas.PresupuestoMillones, y=peliculas.RatingsCriticos, ax=ax[0,1])
k1.set(xlim=(-40,250))
k2.set(xlim=(-40,220))
k3 = sns.violinplot(data=peliculas[peliculas.Genero=="Drama"], x="Año", y="RatingsCriticos", hue="Año", ax=ax[1,0], legend=None)
k4 = sns.kdeplot(x = peliculas.RatingsCriticos, y = peliculas.RatingsAudiencia, shade=True, shade_lowest=False, cmap="Reds", ax=ax[1,1])
k4b = sns.kdeplot(x = peliculas.RatingsCriticos, y = peliculas.RatingsAudiencia, cmap="Reds", ax=ax[1,1])
plt.show()

# %%
sns.set_style("darkgrid")
f, ax = plt.subplots(3,2, figsize=(15,15), sharey=True)
k1 = sns.kdeplot(x=peliculas.PresupuestoMillones, y=peliculas.RatingsAudiencia, ax=ax[0,0])
k2 = sns.kdeplot(x=peliculas.PresupuestoMillones, y=peliculas.RatingsCriticos, ax=ax[0,1])
k1.set(xlim=(-40,250))
k2.set(xlim=(-40,220))
k3 = sns.violinplot(data=peliculas[peliculas.Genero=="Drama"], x="Año", y="RatingsCriticos", hue="Año", ax=ax[1,0], legend=None)
k4 = sns.kdeplot(x = peliculas.RatingsCriticos, y = peliculas.RatingsAudiencia, shade=True, shade_lowest=False, cmap="Reds", ax=ax[1,1])
k4b = sns.kdeplot(x = peliculas.RatingsCriticos, y = peliculas.RatingsAudiencia, cmap="Reds", ax=ax[1,1])
#k5=plt.hist(x=peliculas.RatingsAudiencia, bins=15, ax=ax[2,0]) No funciona
#k6=plt.hist(x=peliculas.RatingsAudiencia, bins=15, ax=ax[2,1]) No funciona 
ax[2,0].hist(x=peliculas.RatingsAudiencia, bins=15)
ax[2,1].hist(x=peliculas.RatingsAudiencia, bins=15)
plt.show()

# %%
#Estilo
sns.set_style("dark", {"axes.facecolor":"black"}) #estilo y color de fondo
f, ax = plt.subplots(3,2, figsize=(15,15), sharey=True)
#Grafico[0,0]
k1 = sns.kdeplot(x=peliculas.PresupuestoMillones, y=peliculas.RatingsAudiencia, cmap="Blues",shade=True, shade_lowest=False, ax=ax[0,0])
k1b = sns.kdeplot(x=peliculas.PresupuestoMillones, y=peliculas.RatingsAudiencia,cmap="Blues", ax=ax[0,0])
#Grafico[0,1]
k2 = sns.kdeplot(x=peliculas.PresupuestoMillones, y=peliculas.RatingsCriticos, cmap="inferno",shade=True, shade_lowest=False, ax=ax[0,1])
k2b = sns.kdeplot(x=peliculas.PresupuestoMillones, y=peliculas.RatingsCriticos, cmap="cool", ax=ax[0,1])
#Grafico[1,0]
k3 = sns.violinplot(data=peliculas[peliculas.Genero=="Drama"], x="Año", y="RatingsCriticos", palette="YlOrRd", ax=ax[1,0], legend=None)
#Grafico[1,1]
k4 = sns.kdeplot(x = peliculas.RatingsCriticos, y = peliculas.RatingsAudiencia, cmap="Reds", shade=True, shade_lowest=False, ax=ax[1,1])
k4b = sns.kdeplot(x = peliculas.RatingsCriticos, y = peliculas.RatingsAudiencia, cmap="Reds", ax=ax[1,1])
#Grafico[2,0]
ax[2,0].hist(x=peliculas.RatingsAudiencia, bins=15)
#Grafico[2,1]
ax[2,1].hist(x=peliculas.RatingsAudiencia, bins=15)
k1.set(xlim=(-40,250))
k2.set(xlim=(-40,220))
plt.show()

# %%
#Ultimos Detalles

# %%
sns.set_style("darkgrid")
lista1 = list()
mis_etiquetas = list()

for gen in peliculas.Genero.cat.categories:
    lista1.append(peliculas[peliculas.Genero==gen].PresupuestoMillones)
    mis_etiquetas.append(gen)
    
h = plt.hist(lista1, bins=30, stacked=True, rwidth= 0.8, label=mis_etiquetas)
plt.legend()
plt.show()

# %%
sns.set_style("whitegrid")
lista1 = list()
mis_etiquetas = list()

for gen in peliculas.Genero.cat.categories:
    lista1.append(peliculas[peliculas.Genero==gen].PresupuestoMillones)
    mis_etiquetas.append(gen)
    
fig2, ax = plt.subplots(1,1)    
fig2.set_size_inches(11.7, 8.27) #tamaño A4 en pulgadas

h2 = plt.hist(lista1, bins=30, stacked=True, rwidth= 0.8, label=mis_etiquetas)
plt.title("Distribucion de Presupuesto para la Peliculas", fontsize=35, color="DarkBlue")
plt.ylabel("Numero de Peliculas", fontsize=25, color="Red")
plt.xlabel("Presupuesto", fontsize=25, color="Green")
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(frameon=True, fancybox=True, framealpha=1, shadow=True, prop={"size":20})
plt.show()
